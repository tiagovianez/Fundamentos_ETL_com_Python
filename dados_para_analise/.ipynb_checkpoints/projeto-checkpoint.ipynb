# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("ocorrencia.csv", parse_dates=['ocorrencia_dia'])
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39711               39711          INCIDENTE GRAVE
# 8              39789               39789                INCIDENTE
# 9              40414               40414                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4             PELOTAS            RS                 SBPK     2010-05-01
# 5            SALVADOR            BA                 ****     2010-06-01
# 6               COARI            AM                 SBUY     2010-07-01
# 7       PARÁ DE MINAS            MG                 ****     2010-10-01
# 8    SÃO PEDRO DO SUL            RS                 ****     2010-10-01
# 9            BRASÍLIA            DF                 SBBR     2010-10-01
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        20:00:00                    0
# 8        21:30:00                    0
# 9        03:00:00                    0

# %%
#Criando a variável schema e atribuindo a ela um DataFrame do Pandera
schema = pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int, nullable=True)  

    }
)
# Out:
#   File "<ipython-input-63-f583205aba6e>", line 5
#     "codigo_ocorrencia": pa.Column(pa.Int),
#                        ^
# SyntaxError: invalid syntax

# %%
#Teste de Validação
schema.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-61-d1378f490e28> in <module>
#       1 #Teste de Validação
# ----> 2 schema.validate(df)
#
# /home/tiago/snap/jupyter/common/lib/python3.7/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     490             random_state=random_state,
#     491             lazy=lazy,
# --> 492             inplace=inplace,
#     493         )
#     494
#
# /home/tiago/snap/jupyter/common/lib/python3.7/site-packages/pandera/schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     604                         msg,
#     605                         failure_cases=scalar_failure_case(colname),
# --> 606                         check="column_in_dataframe",
#     607                     ),
#     608                 )
#
# /home/tiago/snap/jupyter/common/lib/python3.7/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# SchemaError: column 'codigo' not in dataframe
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4             PELOTAS            RS                 SBPK     2010-05-01
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %% [raw]
# pip install pandera

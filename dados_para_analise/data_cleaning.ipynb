# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
#Manipulando dados de um dataframe
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
#Manipulando os dados da linha 3
df.loc[3]
# Out:
# codigo_ocorrencia                        39527
# codigo_ocorrencia2                       39527
# ocorrencia_classificacao              ACIDENTE
# ocorrencia_cidade           LUCAS DO RIO VERDE
# ocorrencia_uf                               MT
# ocorrencia_aerodromo                      ****
# ocorrencia_dia                      04/01/2010
# ocorrencia_hora                       17:30:00
# total_recomendacoes                          0
# Name: 3, dtype: object

# %%
#Manipulando os dados da linha 1 a linha 3
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
#Informando as linhas 10 e 40
df.loc[[10, 40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     10/01/2010
# 40             BELÉM            PA                 ****     28/01/2010
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
#Informando todas as linhas da "ocorrencia_cidade"
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
#Verificando se uma coluna do dataframe é única.
#Ps.: É importante que uma coluna possua valores que não se repitam para ser considerada um index. 
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
#Determinando uma coluna Index (A coluna ficará em negrito, classificando-a como referência)
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
#Manipulando dados da linha do index "40324"
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %%
#Resetando o index original, voltando ao drop de início.
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
#Criando uma coluna de backup
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf
df
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
# ...                               ...                      ...
# 80245                           80245                INCIDENTE
# 80247                           80247                INCIDENTE
# 80251                           80251                INCIDENTE
# 80257                           80257                 ACIDENTE
# 80259                           80259                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# ...

# %%
#Alteração de informações de uma coluna
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'
df
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
# ...                               ...                      ...
# 80245                           80245                INCIDENTE
# 80247                           80247                INCIDENTE
# 80251                           80251                INCIDENTE
# 80257                           80257                 ACIDENTE
# 80259                           80259                    GRAVE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# ...

# %%
#Mostrando na tela as informações de ocorrencia de SP
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40069                           40069                    GRAVE
# 39809                           39809                    GRAVE
# 39828                           39828                    GRAVE
# 39847                           39847                    GRAVE
# 39768                           39768                    GRAVE
# ...                               ...                      ...
# 80234                           80234                    GRAVE
# 80208                           80208                    GRAVE
# 80238                           80238                    GRAVE
# 80244                           80244                    GRAVE
# 80259                           80259                    GRAVE
#
#                    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40069                      SÃO PAULO            SP                 SBMT
# ...

# %%
#Ps.: Todas as alterações devem ser feitas no DataFrame e não no arquivo de origem "CSV"
df
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
# ...                               ...                      ...
# 80245                           80245                INCIDENTE
# 80247                           80247                INCIDENTE
# 80251                           80251                INCIDENTE
# 80257                           80257                 ACIDENTE
# 80259                           80259                    GRAVE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# ...

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# codigo_ocorrencia
# ...

# %%
#Limpeza de Dados | Atribuindo valores que não estão incluidos em um célula utilizando o Pandas (Valor não informando - NotAvaiable)
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
#Dados no qual serão efetuados a limpeza
ocorrencia_uf
**
ocorrencia_aerodromo
****
*****
###!
####
ocorrencia_hora
# Out:
#   File "/tmp/ipykernel_23369/3687993964.py", line 3
#     **
#     ^
# SyntaxError: invalid syntax

# %%
#A função replace permite que faz alterações no dataset como todo
#Ps.: a função 'inplace=True', permite que a alteração ocorra de fato
df.replace(['**', '****', '*****', '###!', '###!', 'NULL'], pd.NA, inplace=True)

# %%
#Contabilizando os dados que não foram informados (NA)
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                 23
# ocorrencia_aerodromo        2432
# ocorrencia_dia                 0
# ocorrencia_hora               22
# total_recomendacoes            0
# dtype: int64

# %%
#Colocando valor nos dados não informados (Em tempo de visualização) 
df.fillna(10, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                   10
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                   10
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# codigo_ocorrencia
# ...

# %%
#Revertendo o valor que estava em 10 para NA (NotAvaiable)
#É importante saber quais dados não informados estamos trabalhando
df.replace([10], pd.NA, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                 23
# ocorrencia_aerodromo        2432
# ocorrencia_dia                 0
# ocorrencia_hora               22
# total_recomendacoes            2
# dtype: int64

# %%
#Alterando o valor de apenas uma coluna.
#Ps.: Lembres-se que a alteração só ocorrerá de fato quando se utilizar o comando 'inplace=True'
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2263
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# ocorrencia_uf_bkp              0
# dtype: int64

# %%
#Criando um backupde uma coluna
df['total_recomendacoes_bkp'] = df.total_recomendacoes
df
# Out:
#                   codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                          40211                INCIDENTE
# 40349                          40349                INCIDENTE
# 40351                          40351                INCIDENTE
# 39527                          39527                 ACIDENTE
# 40324                          40324                INCIDENTE
# ...                              ...                      ...
# 80245                          80245                INCIDENTE
# 80247                          80247                INCIDENTE
# 80251                          80251                INCIDENTE
# 80257                          80257                 ACIDENTE
# 80259                          80259                    GRAVE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 <NA>
# ...

# %%
#Removendo uma coluna "df.drop"| "axis=1" representa o eixo da coluna
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)
df.head()
# Out:
#                   codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                          40211                INCIDENTE
# 40349                          40349                INCIDENTE
# 40351                          40351                INCIDENTE
# 39527                          39527                 ACIDENTE
# 40324                          40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 <NA>
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 <NA>
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# codigo_ocorrencia
# ...

# %%
#Excluindo todos os valores não informados. Ps.: Ele remove as linhas não as células.
df.dropna()
# Out:
#                   codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40349                          40349                INCIDENTE
# 40351                          40351                INCIDENTE
# 40324                          40324                INCIDENTE
# 40215                          40215                INCIDENTE
# 39156                          39156          INCIDENTE GRAVE
# ...                              ...                      ...
# 80244                          80244                    GRAVE
# 80245                          80245                INCIDENTE
# 80247                          80247                INCIDENTE
# 80251                          80251                INCIDENTE
# 80259                          80259                    GRAVE
#
#                    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40349                          BELÉM            PA                 SBBE
# ...

# %%
#Dropando o NA por coluna, ao invés de excluir várias linhas.
df.dropna(subset=['ocorrencia_uf'])
df
# Out:
#                   codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                          40211                INCIDENTE
# 40349                          40349                INCIDENTE
# 40351                          40351                INCIDENTE
# 39527                          39527                 ACIDENTE
# 40324                          40324                INCIDENTE
# ...                              ...                      ...
# 80245                          80245                INCIDENTE
# 80247                          80247                INCIDENTE
# 80251                          80251                INCIDENTE
# 80257                          80257                 ACIDENTE
# 80259                          80259                    GRAVE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 <NA>
# ...

# %%
df
# Out:
#                   codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                          40211                INCIDENTE
# 40349                          40349                INCIDENTE
# 40351                          40351                INCIDENTE
# 39527                          39527                 ACIDENTE
# 40324                          40324                INCIDENTE
# ...                              ...                      ...
# 80245                          80245                INCIDENTE
# 80247                          80247                INCIDENTE
# 80251                          80251                INCIDENTE
# 80257                          80257                 ACIDENTE
# 80259                          80259                    GRAVE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 <NA>
# ...

# %%
#Removendo valores duplicados de um DataFrame
df.drop_duplicates(inplace=True)
df
# Out:
#                   codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                          40211                INCIDENTE
# 40349                          40349                INCIDENTE
# 40351                          40351                INCIDENTE
# 39527                          39527                 ACIDENTE
# 40324                          40324                INCIDENTE
# ...                              ...                      ...
# 80245                          80245                INCIDENTE
# 80247                          80247                INCIDENTE
# 80251                          80251                INCIDENTE
# 80257                          80257                 ACIDENTE
# 80259                          80259                    GRAVE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 <NA>
# ...
